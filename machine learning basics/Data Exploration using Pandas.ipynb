# %% [markdown]
# Learn Data Exploration using Pandas Library in Python

# %%
#Importing required libraries 
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Download the dataset from https://www.kaggle.com/uciml/pima-indians-diabetes-database/download
os.chdir('Downloads')

# %%
os.getcwd()
# Out:
# '/Users/lakshmikanth/Downloads'

# %% [markdown]
# #Read Dataset

# %%
#read dataset, reading csv files using pandas
data = pd.read_csv('diabetes.csv')

# %% [markdown]
# #Getting Preview of Data

# %%
#looking at top n records
data.head() #specify the number required to display, For example data.head(10) displays first 10 observations
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#looking at bottom n records
data.tail(3)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#getting column names
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'InsulinValue', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# #Renaming columns of dataframe

# %%
#renaming column name
data.rename(columns={'Insulin':'InsulinValue'},inplace=True)

# %%
#getting column names
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'InsulinValue', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#checking is there any null values in the dataset
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# InsulinValue                0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#describe dataset
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# InsulinValue              768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# InsulinValue               30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
data.cov()
# Out:
#                           Pregnancies      Glucose  BloodPressure  \
# Pregnancies                 11.354056    13.947131       9.214538
# Glucose                     13.947131  1022.248314      94.430956
# BloodPressure                9.214538    94.430956     374.647271
# SkinThickness               -4.390041    29.239183      64.029396
# InsulinValue               -28.555231  1220.935799     198.378412
# BMI                          0.469774    55.726987      43.004695
# DiabetesPedigreeFunction    -0.037426     1.454875       0.264638
# Age                         21.570620    99.082805      54.523453
# Outcome                      0.356618     7.115079       0.600697
#
#                           SkinThickness  InsulinValue         BMI  \
# Pregnancies                   -4.390041    -28.555231    0.469774
# Glucose                       29.239183   1220.935799   55.726987
# BloodPressure                 64.029396    198.378412   43.004695
# SkinThickness                254.473245    802.979941   49.373869
# InsulinValue                 802.979941  13281.180078  179.775172
# BMI                           49.373869    179.775172   62.159984
# DiabetesPedigreeFunction       0.972136      7.066681    0.367405
# Age                          -21.381023    -57.143290    3.360330
# Outcome                        0.568747      7.175671    1.100638
#
#                           DiabetesPedigreeFunction         Age   Outcome
# Pregnancies                              -0.037426   21.570620  0.356618
# Glucose                                   1.454875   99.082805  7.115079
# BloodPressure                             0.264638   54.523453  0.600697
# SkinThickness                             0.972136  -21.381023  0.568747
# InsulinValue                              7.066681  -57.143290  7.175671
# BMI                                       0.367405    3.360330  1.100638
# DiabetesPedigreeFunction                  0.109779    0.130772  0.027472
# Age                                       0.130772  138.303046  1.336953
# Outcome                                   0.027472    1.336953  0.227483

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# InsulinValue                -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                           InsulinValue       BMI  DiabetesPedigreeFunction  \
# Pregnancies                  -0.073535  0.017683                 -0.033523
# Glucose                       0.331357  0.221071                  0.137337
# BloodPressure                 0.088933  0.281805                  0.041265
# SkinThickness                 0.436783  0.392573                  0.183928
# InsulinValue                  1.000000  0.197859                  0.185071
# BMI                           0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction      0.185071  0.140647                  1.000000
# Age                          -0.042163  0.036242                  0.033561
# Outcome                       0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# InsulinValue             -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fe23400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11fe311d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11feaeac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x18211860b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x18211b4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22580c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a225be208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225ee7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a225ee828>]],
#       dtype=object)

# %%
data.shape
# Out:
# (768, 9)

# %%
cor_mat = data.corr()
cor_mat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col0 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col1 {
#             background-color:  #516ddb;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col2 {
#             background-color:  #5a78e4;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col3 {
#             background-color:  #4358cb;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col6 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col7 {
#             background-color:  #f1cdba;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row0_col8 {
#             background-color:  #6f92f3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col0 {
#             background-color:  #799cf8;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col1 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col2 {
#             background-color:  #5e7de7;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col3 {
#             background-color:  #6b8df0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col4 {
#             background-color:  #b9d0f9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col5 {
#             background-color:  #7ea1fa;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col6 {
#             background-color:  #6f92f3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col7 {
#             background-color:  #abc8fd;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row1_col8 {
#             background-color:  #c9d7f0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col0 {
#             background-color:  #7da0f9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col1 {
#             background-color:  #5977e3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col2 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col3 {
#             background-color:  #9abbff;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col4 {
#             background-color:  #6a8bef;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col5 {
#             background-color:  #93b5fe;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col6 {
#             background-color:  #506bda;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col7 {
#             background-color:  #a5c3fe;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row2_col8 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col0 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col1 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col2 {
#             background-color:  #7295f4;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col3 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col4 {
#             background-color:  #d6dce4;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col5 {
#             background-color:  #bad0f8;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col6 {
#             background-color:  #7ea1fa;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col7 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row3_col8 {
#             background-color:  #3d50c3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col0 {
#             background-color:  #3c4ec2;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col1 {
#             background-color:  #9bbcff;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col2 {
#             background-color:  #4961d2;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col3 {
#             background-color:  #dbdcde;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col4 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col5 {
#             background-color:  #7597f6;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col6 {
#             background-color:  #80a3fa;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col7 {
#             background-color:  #4e68d8;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row4_col8 {
#             background-color:  #4f69d9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col0 {
#             background-color:  #5673e0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col1 {
#             background-color:  #7295f4;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col2 {
#             background-color:  #8db0fe;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col3 {
#             background-color:  #d1dae9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col4 {
#             background-color:  #8db0fe;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col5 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col6 {
#             background-color:  #7093f3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col7 {
#             background-color:  #6485ec;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row5_col8 {
#             background-color:  #8badfd;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col0 {
#             background-color:  #485fd1;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col1 {
#             background-color:  #5470de;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col2 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col3 {
#             background-color:  #93b5fe;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col4 {
#             background-color:  #89acfd;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col5 {
#             background-color:  #6282ea;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col6 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col7 {
#             background-color:  #6384eb;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row6_col8 {
#             background-color:  #5e7de7;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col0 {
#             background-color:  #efcfbf;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col1 {
#             background-color:  #81a4fb;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col2 {
#             background-color:  #7da0f9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col3 {
#             background-color:  #3b4cc0;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col4 {
#             background-color:  #4358cb;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col5 {
#             background-color:  #3f53c6;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col6 {
#             background-color:  #4e68d8;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col7 {
#             background-color:  #b40426;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row7_col8 {
#             background-color:  #7699f6;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row8_col0 {
#             background-color:  #97b8ff;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row8_col1 {
#             background-color:  #cbd8ee;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row8_col2 {
#             background-color:  #4257c9;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row8_col3 {
#             background-color:  #7093f3;
#         }    #T_632fab74_e74a_11e9_9820_d0817ab20186row8_col4 {
#             bac

# %%
#separating diabetic/ healthy data
diabetes = data[data.Outcome != 0]
healthy = data[data.Outcome ==1]

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
die_data = data.Outcome.value_counts().values.tolist()
die_data_labels = ['Diabetes','Healthy']

# %%
plt.pie(die_data,labels = die_data_labels,autopct='%.f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a22efb908>,
#   <matplotlib.patches.Wedge at 0x1a22efbfd0>],
#  [Text(-0.5025943242672991, 0.9784676515931925, 'Diabetes'),
#   Text(0.5025944158780503, -0.9784676045369114, 'Healthy')],
#  [Text(-0.27414235869125403, 0.5337096281417413, '65%'),
#   Text(0.2741424086607547, -0.5337096024746789, '35%')])

# %%
data[['Glucose','BloodPressure','SkinThickness','InsulinValue','BMI']] = data[['Glucose','BloodPressure','SkinThickness','InsulinValue','BMI']].replace(0,np.NaN)

# %%
null_feat = pd.DataFrame(len(data['Outcome']) - data.isnull().sum(), columns = ['null_feature'])
null_feat
# Out:
#                           null_feature
# Pregnancies                        768
# Glucose                            763
# BloodPressure                      733
# SkinThickness                      541
# InsulinValue                       394
# BMI                                757
# DiabetesPedigreeFunction           768
# Age                                768
# Outcome                            768

# %%
percentage_null = pd.DataFrame((len(data['Outcome']) - (len(data['Outcome']) - data.isnull().sum()))/len(data['Outcome'])*100, columns = ['null_percent'])
percentage_null = percentage_null.round(2)
percentage_null
# Out:
#                           null_percent
# Pregnancies                       0.00
# Glucose                           0.65
# BloodPressure                     4.56
# SkinThickness                    29.56
# InsulinValue                     48.70
# BMI                               1.43
# DiabetesPedigreeFunction          0.00
# Age                               0.00
# Outcome                           0.00

# %%
percentage_null['null_percent'].plot.bar()

# %%
combined_df = pd.concat([null_feat,percentage_null],axis = 1)

# %%
combined_df.T
# Out:
#               Pregnancies  Glucose  BloodPressure  SkinThickness  \
# null_feature        768.0   763.00         733.00         541.00
# null_percent          0.0     0.65           4.56          29.56
#
#               InsulinValue     BMI  DiabetesPedigreeFunction    Age  Outcome
# null_feature         394.0  757.00                     768.0  768.0    768.0
# null_percent          48.7    1.43                       0.0    0.0      0.0

# %%
data.boxplot(figsize=(20,15),rot=45, fontsize=15)

# %%
target= data['Outcome']
Predictor = data.iloc[:,:-1]

# %%
sns.pairplot(Predictor)
